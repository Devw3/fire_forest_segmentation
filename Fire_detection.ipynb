# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.4/750.4 kB 5.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !pip install torch torchvision
# !pip install numpy opencv-python
# !pip install utils
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
import cv2
import torch
import numpy as np
from torchvision import transforms
import matplotlib.pyplot as plt
from PIL import Image
import torch.nn.functional as func
import pandas as pd
from ultralytics import YOLO

def detect_people(image):
  input_img = Image.open(image)

  transform = transform.Compose([transforms.Resize((640, 640)), transforms.ToTensor()])

  img = transform(input_img).unsqueeze(0)
  res_tenser =

# %%
# !pip install utils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13906 sha256=fdac079476edd04d48021d275f72f2b3fb5fcd5dfc44c0d6ea4223787ca665f0
#   Stored in directory: /root/.cache/pip/wheels/b8/39/f5/9d0ca31dba85773ececf0a7f5469f18810e1c8a8ed9da28ca7
# Successfully built utils
# ...

# %%
import torch
from PIL import Image
from pathlib import Path
from torchvision.ops import nms
from ultralytics import YOLO
from torchvision import transforms

model = YOLO('yolov5s.pt')

image_path = '/content/fire_detect.jpg'
img = Image.open(image_path)

transform = transforms.Compose([transforms.Resize((640, 640)), transforms.ToTensor()])
tensor = transform(img).unsqueeze(0)

pred = model(tensor)

pred_boxes = pred[0]
print(pred_boxes)
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
#
# 0: 640x640 (no detections), 537.9ms
# Speed: 0.0ms preprocess, 537.9ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
import os
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow import keras

from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

def train_model(train_data)
    model = keras.Sequential([
      model.add(Conv2D(32, (3, 3), input_shape=(3, 32, 32), activation='relu', padding='same'))
      Dense(10, activation='softmax')
    ])

# %%
from PIL import Image
from torchvision import transforms
train_path = '/content/fire_detect.jpg'
test_path = '/content/fire_detect.jpg'
val_path = '/content/fire_detect.jpg'

train = Image.open(image_path)
test = Image.open(image_path)
val = Image.open(image_path)

def image_toTenser(image):
    transform = transforms.Compose([transforms.Resize((640, 640)), transforms.ToTensor()])
    tensor = transform(image).unsqueeze(0)
    tensor

tenser_train = image_toTenser(train)
tenser_test = image_toTenser(test)
tenser_val = image_toTenser(val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d1076c711e1d> in <cell line: 14>()
#      12     tensor
#      13
# ---> 14 tenser_train = image_toTenser(data)
#      15 tenser_train = image_toTenser(data)
#
# NameError: name 'data' is not defined
